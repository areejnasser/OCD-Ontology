# %% [markdown]
# # Import the dependancy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

if not os.path.exists("images"):
    os.mkdir("images")

# %%
pwd
# Out:
# '/Users/areejnasser/Desktop/survey-analysis'

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %%
# !conda install -c conda-forge python-kaleido

# %% [markdown]
# # **Survey data **

# %% [markdown]
# - The mean of all liker scale value (agree, disagree, not sure).
# Mean or median score analysis: This involves assigning a numerical value to each response category (e.g., 1 for "disagree," 2 for "agree," 3 for "not sure") and then calculating the mean or median score for each question. This can give you a sense of the overall level of agreement or disagreement with each statement.
# Factor analysis: This involves looking for underlying factors or themes that may be driving the responses to certain questions. For example, if several questions (3 first question) are related to (Intrusive thought definition), you could perform a factor analysis to see if there are any underlying factors (e.g.,emotion, functional impairment, time) that are associated with the responses).

# %%
# read the data 

df  = pd.read_csv('/Users/areejnasser/Desktop/survey-analysis/survey3.csv',  header= 0, encoding= 'unicode_escape')

# %% [markdown]
# # **Delete the first 16 demographic questions **

# %%
df = df.drop(df.columns[:17], axis=1)

# Save the modified data to a new CSV file
df.to_csv('modified_data.csv', index=False)

# %%
df
# Out:
#    In OCD, an Intrusive Thought, characterising an Obsession, is a Thought that is always associated with negative emotions (e.g. distress).\n\nExample: A new mum has distressing thoughts about dropping her baby while carrying him, and causing him harm.\n\n  \
# 0                                               Agree
# 1                                            Not sure
# 2                                            Disagree
# 3                                               Agree
# 4                                               Agree
# 5                                               Agree
# 6                                               Agree
# 7                                            Disagree
# 8                                               Agree
# 9                                            Disagree
# 10                                           Disagree
# 11                                                NaN
# 12                                           Disagree
# ...

# %% [markdown]
# # **Delete the qualitative questions **

# %%
# Drop columns that has all NaN values
df2=df.dropna(axis=1, how='all')

# %%
df2
# Out:
#    In OCD, an Intrusive Thought, characterising an Obsession, is a Thought that is always associated with negative emotions (e.g. distress).\n\nExample: A new mum has distressing thoughts about dropping her baby while carrying him, and causing him harm.\n\n  \
# 0                                               Agree
# 1                                            Not sure
# 2                                            Disagree
# 3                                               Agree
# 4                                               Agree
# 5                                               Agree
# 6                                               Agree
# 7                                            Disagree
# 8                                               Agree
# 9                                            Disagree
# 10                                           Disagree
# 11                                                NaN
# 12                                           Disagree
# ...

# %%
# Drop columns that has all NaN values
df2=df2.dropna(axis=0, how='all')

# %%
df2
# Out:
#    In OCD, an Intrusive Thought, characterising an Obsession, is a Thought that is always associated with negative emotions (e.g. distress).\n\nExample: A new mum has distressing thoughts about dropping her baby while carrying him, and causing him harm.\n\n  \
# 0                                               Agree
# 1                                            Not sure
# 2                                            Disagree
# 3                                               Agree
# 4                                               Agree
# 5                                               Agree
# 6                                               Agree
# 7                                            Disagree
# 8                                               Agree
# 9                                            Disagree
# 10                                           Disagree
# 12                                           Disagree
# 13                                              Agree
# ...

# %%
df2.dropna(axis=1,thresh=4,inplace=True)
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/137689787.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#    In OCD, an Intrusive Thought, characterising an Obsession, is a Thought that is always associated with negative emotions (e.g. distress).\n\nExample: A new mum has distressing thoughts about dropping her baby while carrying him, and causing him harm.\n\n  \
# 0                                               Agree
# 1                                            Not sure
# 2                                            Disagree
# 3                                               Agree
# 4                                               Agree
# 5                                               Agree
# 6                                               Agree
# 7                                            Disagree
# 8                                               Agree
# 9                                            Disagree
# 10                                           Disagree
# 12                                           Disagree
# 13                                              Agree
# ...

# %%
df2.fillna('Agree', inplace=True)
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/2706463128.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#    In OCD, an Intrusive Thought, characterising an Obsession, is a Thought that is always associated with negative emotions (e.g. distress).\n\nExample: A new mum has distressing thoughts about dropping her baby while carrying him, and causing him harm.\n\n  \
# 0                                               Agree
# 1                                            Not sure
# 2                                            Disagree
# 3                                               Agree
# 4                                               Agree
# 5                                               Agree
# 6                                               Agree
# 7                                            Disagree
# 8                                               Agree
# 9                                            Disagree
# 10                                           Disagree
# 12                                           Disagree
# 13                                              Agree
# ...

# %%
lst = df2.columns
lst
# Out:
# Index(['In OCD, an Intrusive Thought, characterising an Obsession, is a Thought that is always associated with negative emotions (e.g. distress).\n\nExample: A new mum has distressing thoughts about dropping her baby while carrying him, and causing him harm.\n\n',
#        'In OCD,  an Intrusive Thought, characterising an Obsession, tend to frequently occupy a person's mind during her daily life.\n\nExample: The mum experiences the distressing thoughts of dropping her baby many times during the day. ',
#        'In OCD, an Intrusive Thought, characterising an Obsession, will impact the person's normal activities (e.g. isolation from social circles, inability to work).  \n\nExample: As a result of the distressing thoughts of dropping the baby, the mum refuses to carry her child.',
# ...

# %%
colTo_Label= {k: 'Q'+str(v) for v, k in enumerate(lst,1)}
colTo_Label
# Out:
# {'In OCD, an Intrusive Thought, characterising an Obsession, is a Thought that is always associated with negative emotions (e.g. distress).\n\nExample: A new mum has distressing thoughts about dropping her baby while carrying him, and causing him harm.\n\n': 'Q1',
#  "In OCD,  an Intrusive Thought, characterising an Obsession, tend to frequently occupy a person's mind during her daily life.\n\nExample: The mum experiences the distressing thoughts of dropping her baby many times during the day. ": 'Q2',
#  "In OCD, an Intrusive Thought, characterising an Obsession, will impact the person's normal activities (e.g. isolation from social circles, inability to work).  \n\nExample: As a result of the distressing thoughts of dropping the baby, the mum refuses to carry her child.": 'Q3',
# ...

# %%
for i in range(len(df2.columns)):
  name= colTo_Label[df2.columns[i]]
name
# Out:
# 'Q12'

# %%
for i in range(len(df2.columns)):
  name= colTo_Label[df2.columns[i]]
  
  data= df2.iloc[:, i].value_counts().to_dict()
data
# Out:
# {'Disagree': 14, 'Agree': 10, 'Not sure': 7}

# %%
QuestionsList, AgreeList, DisagreeList, NotSureList= [], [], [], []
for i in range(len(df2.columns)):
  name= colTo_Label[df2.columns[i]]
  
  data= df2.iloc[:, i].value_counts().to_dict()
  QuestionsList.append(name)
  AgreeList.append(data.get('Agree'))
  DisagreeList.append(data.get('Disagree'))
  NotSureList.append(data.get('Not sure'))

# %%
mydf = pd.DataFrame(list(zip(QuestionsList, AgreeList, DisagreeList, NotSureList)), columns = ['Questions', 'Agree', 'Disagree','Not sure'])

# %%
mydf
# Out:
#    Questions  Agree  Disagree  Not sure
# 0         Q1     22       7.0       2.0
# 1         Q2     30       1.0       NaN
# 2         Q3     29       NaN       2.0
# 3         Q4     13      11.0       7.0
# 4         Q5     30       NaN       1.0
# 5         Q6     26       2.0       3.0
# 6         Q7     17      12.0       2.0
# 7         Q8     27       NaN       4.0
# 8         Q9     10       7.0      14.0
# 9        Q10     29       1.0       1.0
# 10       Q11     29       NaN       2.0
# 11       Q12     10      14.0       7.0

# %%
finalDf= mydf.fillna(0)

# %%
finalDf
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q1            22       7.0       2.0
# Q2            30       1.0       0.0
# Q3            29       0.0       2.0
# Q4            13      11.0       7.0
# Q5            30       0.0       1.0
# Q6            26       2.0       3.0
# Q7            17      12.0       2.0
# Q8            27       0.0       4.0
# Q9            10       7.0      14.0
# Q10           29       1.0       1.0
# Q11           29       0.0       2.0
# Q12           10      14.0       7.0

# %% [markdown]
# # **The non-negative statments **

# %%
posStatment = finalDf.drop(index=[3,6,11])

# %%
negStatment = finalDf.drop(index=[0,1,2,4,5,7,8,9,10])

# %%
print(posStatment)
# Out:
#    Questions  Agree  Disagree  Not sure
# 0         Q1     22       7.0       2.0
# 1         Q2     30       1.0       0.0
# 2         Q3     29       0.0       2.0
# 4         Q5     30       0.0       1.0
# 5         Q6     26       2.0       3.0
# 7         Q8     27       0.0       4.0
# 8         Q9     10       7.0      14.0
# 9        Q10     29       1.0       1.0
# 10       Q11     29       0.0       2.0

# %%
print(negStatment)
# Out:
#    Questions  Agree  Disagree  Not sure
# 3         Q4     13      11.0       7.0
# 6         Q7     17      12.0       2.0
# 11       Q12     10      14.0       7.0

# %%
posStatment.reset_index(inplace =True)

# %%
negStatment.reset_index(inplace =True)

# %% [markdown]
# # **Visual analysis of positive statments (the frequency of aggrement , disaggrement and not sure)**

# %%
import plotly.express as px
fig = px.bar(posStatment, y="Questions", x=["Agree", "Disagree", "Not sure"],)
fig.update_layout(
    autosize=True,
    width=800,
    height=500,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),

)


fig.show()

# %% [markdown]
# # **Visual analysis of negative statments (the frequency of aggrement , disaggrement and not sure)**

# %%
import plotly.express as px
fig = px.bar(negStatment, y="Questions", x=["Agree", "Disagree", "Not sure"],)
fig.update_layout(
    autosize=True,
    width=800,
    height=500,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),

)


fig.show()

# %%
fig.write_image("images/positive-statement.png",  engine='kaleido')

# %%
posStatment.index= posStatment['Questions']
negStatment.index= negStatment['Questions']

# %%
posStatment.drop(columns=['index','Questions'],inplace=True)
negStatment.drop(columns=['index','Questions'],inplace=True)

# %%
posStatment
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q1            22       7.0       2.0
# Q2            30       1.0       0.0
# Q3            29       0.0       2.0
# Q5            30       0.0       1.0
# Q6            26       2.0       3.0
# Q8            27       0.0       4.0
# Q9            10       7.0      14.0
# Q10           29       1.0       1.0
# Q11           29       0.0       2.0

# %%
negStatment
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q4            13      11.0       7.0
# Q7            17      12.0       2.0
# Q12           10      14.0       7.0

# %% [markdown]
# # **The sum, mean, median of (Agree, disagree, not sure) for positive and negative statements.**

# %%
posStatment.loc['sum'] = posStatment.sum()
negStatment.loc['sum'] = negStatment.sum()

# %%
posStatment.loc['mean'] = posStatment.mean()
negStatment.loc['mean'] = negStatment.mean()

# %%
posStatment.loc['median'] = posStatment.median()
negStatment.loc['median'] = negStatment.median()

# %%
posStatment.loc['mode'] = posStatment.mode().iloc()[0]
negStatment.loc['mode'] = negStatment.mode().iloc()[0]

# %%
posStatment
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q1          22.0       7.0       2.0
# Q2          30.0       1.0       0.0
# Q3          29.0       0.0       2.0
# Q5          30.0       0.0       1.0
# Q6          26.0       2.0       3.0
# Q8          27.0       0.0       4.0
# Q9          10.0       7.0      14.0
# Q10         29.0       1.0       1.0
# Q11         29.0       0.0       2.0
# sum        232.0      18.0      29.0
# mean        46.4       3.6       5.8
# median      29.0       1.0       2.0
# mode        29.0       0.0       2.0

# %%
posStatment.loc['percentage'] = posStatment.value_counts()
negStatment.loc['percentage'] = negStatment.value_counts()

# %%
posStatment.loc['percentage']['Agree']= round((posStatment.loc['sum']['Agree']/posStatment.loc['sum'].sum())*100)
posStatment.loc['percentage']['Disagree']= round((posStatment.loc['sum']['Disagree']/posStatment.loc['sum'].sum())*100)
posStatment.loc['percentage']['Not sure']= round((posStatment.loc['sum']['Not sure']/posStatment.loc['sum'].sum())*100)
negStatment.loc['percentage']['Agree']= round((negStatment.loc['sum']['Agree']/negStatment.loc['sum'].sum())*100)
negStatment.loc['percentage']['Disagree']= round((negStatment.loc['sum']['Disagree']/negStatment.loc['sum'].sum())*100)
negStatment.loc['percentage']['Not sure']= round((negStatment.loc['sum']['Not sure']/negStatment.loc['sum'].sum())*100)

# %%
posStatment
# Out:
#             Agree  Disagree  Not sure
# Questions
# Q1           22.0       7.0       2.0
# Q2           30.0       1.0       0.0
# Q3           29.0       0.0       2.0
# Q5           30.0       0.0       1.0
# Q6           26.0       2.0       3.0
# Q8           27.0       0.0       4.0
# Q9           10.0       7.0      14.0
# Q10          29.0       1.0       1.0
# Q11          29.0       0.0       2.0
# sum         232.0      18.0      29.0
# mean         46.4       3.6       5.8
# median       29.0       1.0       2.0
# mode         29.0       0.0       2.0
# percentage   83.0       6.0      10.0

# %%
dfPercentage= posStatment.filter(items=['percentage'], axis=0)
dfPercentage1= negStatment.filter(items=['percentage'], axis=0)

# %%
dfPercentage
# Out:
#             Agree  Disagree  Not sure
# Questions
# percentage   83.0       6.0      10.0

# %% [markdown]
# # **Visual analysis of the precentage of (Agree, Disagree, Not sure) of the Positive statment **

# %%
import plotly.express as px

fig = px.bar(dfPercentage, x=["Agree", "Disagree", "Not sure"],height=400)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="Positive statments")


fig.show()

# %% [markdown]
# # **Visual analysis of the precentage of (Agree, Disagree, Not sure) of the Negative statment **

# %%
import plotly.express as px

fig = px.bar(dfPercentage1, x=["Agree", "Disagree", "Not sure"],height=400)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)
fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="Negative statments")


fig.show()

# %%
fig.write_image("images/precen-neg-statement.png",  engine='kaleido')

# %% [markdown]
# # **Questions related to Intrusive thought **

# %%
NewDataFrame= finalDf.copy()

# %%
NewDataFrame
# Out:
#    Questions  Agree  Disagree  Not sure
# 0         Q1     22       7.0       2.0
# 1         Q2     30       1.0       0.0
# 2         Q3     29       0.0       2.0
# 3         Q4     13      11.0       7.0
# 4         Q5     30       0.0       1.0
# 5         Q6     26       2.0       3.0
# 6         Q7     17      12.0       2.0
# 7         Q8     27       0.0       4.0
# 8         Q9     10       7.0      14.0
# 9        Q10     29       1.0       1.0
# 10       Q11     29       0.0       2.0
# 11       Q12     10      14.0       7.0

# %%
NewDataFrame.index= NewDataFrame['Questions']

# %%
NewDataFrame.drop(columns=['Questions'],inplace=True)

# %%
NewDataFrame
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q1            22       7.0       2.0
# Q2            30       1.0       0.0
# Q3            29       0.0       2.0
# Q4            13      11.0       7.0
# Q5            30       0.0       1.0
# Q6            26       2.0       3.0
# Q7            17      12.0       2.0
# Q8            27       0.0       4.0
# Q9            10       7.0      14.0
# Q10           29       1.0       1.0
# Q11           29       0.0       2.0
# Q12           10      14.0       7.0

# %%
NewDataFrame.loc['Q1Q2Q3'] = NewDataFrame.iloc()[:3].sum()

# %%
NewDataFrame
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q1          22.0       7.0       2.0
# Q2          30.0       1.0       0.0
# Q3          29.0       0.0       2.0
# Q4          13.0      11.0       7.0
# Q5          30.0       0.0       1.0
# Q6          26.0       2.0       3.0
# Q7          17.0      12.0       2.0
# Q8          27.0       0.0       4.0
# Q9          10.0       7.0      14.0
# Q10         29.0       1.0       1.0
# Q11         29.0       0.0       2.0
# Q12         10.0      14.0       7.0
# Q1Q2Q3      81.0       8.0       4.0

# %%
dfCompare= NewDataFrame.filter(items=['Q1Q2Q3', 'Q4'], axis=0)

# %%
dfCompare
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q1Q2Q3      81.0       8.0       4.0
# Q4          13.0      11.0       7.0

# %%
dfCompare.reset_index(inplace =True)

# %%
NewDataFrame1= finalDf.copy()
NewDataFrame1.index= NewDataFrame1['Questions']
NewDataFrame1.drop(columns=['Questions'],inplace=True)
NewDataFrame1.loc['Q1'] = NewDataFrame1.iloc()[:3].sum()

# %% [markdown]
# # **The visual analysis of the sum of the (Agree, Disagree, not sure) of Intrusive thought (Q1,Q2,Q3 and Q4)**

# %%
import plotly.express as px
fig = px.bar(dfCompare, x=["Agree", "Disagree", "Not sure"],)
fig.update_layout(
    autosize=True,
    width=800,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),

)


fig.show()

# %% [markdown]
# # **Compute the sum of and the precentage of Agree, disagree and not sure in the nagative statment of intrusive thought (Q4)**

# %%
posStatment_thought = dfCompare.drop(index=[1])

# %%
negStatment_thought = dfCompare.drop(index=[0])

# %%
posStatment_thought
# Out:
#   Questions  Agree  Disagree  Not sure
# 0    Q1Q2Q3   81.0       8.0       4.0

# %%
posStatment_thought.reset_index(inplace =True)
negStatment_thought.reset_index(inplace =True)

# %%
posStatment_thought.drop(columns=['index','Questions'],inplace=True)
negStatment_thought.drop(columns=['index','Questions'],inplace=True)

# %%
posStatment_thought.loc['sum'] = posStatment_thought.sum()
negStatment_thought.loc['sum'] = negStatment_thought.sum()

# %%
posStatment_thought.loc['percentage'] = posStatment_thought.value_counts()
negStatment_thought.loc['percentage'] = negStatment_thought.value_counts()

# %%
posStatment_thought.loc['percentage']['Agree']= round((posStatment_thought.loc['sum']['Agree']/posStatment_thought.loc['sum'].sum())*100)
posStatment_thought.loc['percentage']['Disagree']= round((posStatment_thought.loc['sum']['Disagree']/posStatment_thought.loc['sum'].sum())*100)
posStatment_thought.loc['percentage']['Not sure']= round((posStatment_thought.loc['sum']['Not sure']/posStatment_thought.loc['sum'].sum())*100)
negStatment_thought.loc['percentage']['Agree']= round((negStatment_thought.loc['sum']['Agree']/negStatment_thought.loc['sum'].sum())*100)
negStatment_thought.loc['percentage']['Disagree']= round((negStatment_thought.loc['sum']['Disagree']/negStatment_thought.loc['sum'].sum())*100)
negStatment_thought.loc['percentage']['Not sure']= round((negStatment_thought.loc['sum']['Not sure']/negStatment_thought.loc['sum'].sum())*100)

# %%
dfPercentage_thought= posStatment_thought.filter(items=['percentage'], axis=0)
dfPercentage1_thought= negStatment_thought.filter(items=['percentage'], axis=0)

# %%
dfPercentage_thought.reset_index(inplace =True)

# %%
dfPercentage1_thought.reset_index(inplace =True)

# %% [markdown]
# # **The precentage of positive statment of intrusive thought**

# %%
dfPercentage_thought
# Out:
#         index  Agree  Disagree  Not sure
# 0  percentage   87.0       9.0       4.0

# %% [markdown]
# # **The precentage of negative statment of intrusive thought**

# %%
dfPercentage1_thought
# Out:
#             Agree  Disagree  Not sure
# percentage   42.0      35.0      23.0

# %%
import plotly.express as px

fig = px.bar(dfPercentage_thought, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)


fig.show()

# %%
import plotly.express as px

fig = px.bar(dfPercentage1_thought, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)


fig.show()

# %% [markdown]
# # **Questions related to Intrusive urge**

# %%
urge= finalDf.iloc[5:7]
urge
# Out:
#   Questions  Agree  Disagree  Not sure
# 5        Q6     26       2.0       3.0
# 6        Q7     17      12.0       2.0

# %%
urge.index= urge['Questions']

# %%
urge.drop(columns=['Questions'],inplace=True)
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1000375291.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
urge
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q6            26       2.0       3.0
# Q7            17      12.0       2.0

# %%
import plotly.express as px

fig = px.bar(urge,  x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=700,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)


fig.show()

# %%
fig.write_image("images/intrusive-urge.png",  engine='kaleido')

# %%
urge.loc['sum'] = urge.sum()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1243699925.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
urge.loc['percentage'] = urge.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1170249468.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
urge.loc['percentage']['Agree']= round((urge.loc['sum']['Agree']/urge.loc['sum'].sum())*100)
urge.loc['percentage']['Disagree']= round((urge.loc['sum']['Disagree']/urge.loc['sum'].sum())*100)
urge.loc['percentage']['Not sure']= round((urge.loc['sum']['Not sure']/urge.loc['sum'].sum())*100)

# %%
dfPercentage_urge= urge.filter(items=['percentage'], axis=0)
dfPercentage_urge.reset_index(inplace =True)
dfPercentage_urge.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_urge, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="Statment related to 'Urge' ")
fig.show()

# %% [markdown]
# # **Ouestion related to Intrusive image **

# %%
image = finalDf.iloc[4:5]
image
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q5            30       0.0       1.0

# %%
import plotly.express as px
#fig = px.bar(finalDf, y="Questions", x=["Agree", "Disagree", "Not sure"],height=200)
fig = px.bar(image,y="Questions", x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=700,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)


fig.show()

# %%
image.loc['sum'] = image.sum()
image.loc['percentage'] = image.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1261794162.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1261794162.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
image.loc['percentage']['Agree']= round((image.loc['sum']['Agree']/image.loc['sum'].sum())*100)
image.loc['percentage']['Disagree']= round((image.loc['sum']['Disagree']/image.loc['sum'].sum())*100)
image.loc['percentage']['Not sure']= round((image.loc['sum']['Not sure']/image.loc['sum'].sum())*100)

# %%
dfPercentage_image= image.filter(items=['percentage'], axis=0)
dfPercentage_image.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_image, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="Statment related to 'Mental image' ")
fig.show()

# %% [markdown]
# # **Question related o obsession **

# %%
obse = finalDf.iloc[7:9]
obse
# Out:
#   Questions  Agree  Disagree  Not sure
# 7        Q8     27       0.0       4.0
# 8        Q9     10       7.0      14.0

# %%
import plotly.express as px
#fig = px.bar(finalDf, y="Questions", x=["Agree", "Disagree", "Not sure"],height=200)
fig = px.bar(obse,y="Questions", x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=700,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)


fig.show()

# %%
import plotly.express as px

fig = px.bar(dfPercentage_obse, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="Statment related to 'Obsession' ")
fig.show()

# %% [markdown]
# # **Questions related to Compulsion**

# %%
compul = finalDf.iloc[9:12]
compul
# Out:
#    Questions  Agree  Disagree  Not sure
# 9        Q10     29       1.0       1.0
# 10       Q11     29       0.0       2.0
# 11       Q12     10      14.0       7.0

# %%
import plotly.express as px
#fig = px.bar(finalDf, y="Questions", x=["Agree", "Disagree", "Not sure"],height=200)
fig = px.bar(compul, y="Questions", x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=700,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)


fig.show()

# %%
compul.index= compul['Questions']

# %%
compul.drop(columns=['Questions'],inplace=True)
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1220190019.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
compul.loc['sum'] = compul.sum()
compul.loc['percentage'] = compul.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/863777380.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/863777380.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
compul.loc['percentage']['Agree']= round((compul.loc['sum']['Agree']/compul.loc['sum'].sum())*100)
compul.loc['percentage']['Disagree']= round((compul.loc['sum']['Disagree']/compul.loc['sum'].sum())*100)
compul.loc['percentage']['Not sure']= round((compul.loc['sum']['Not sure']/compul.loc['sum'].sum())*100)

# %%
dfPercentage_compul= urge.filter(items=['percentage'], axis=0)
dfPercentage_compul.reset_index(inplace =True)
dfPercentage_compul.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_compul, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="Statment related to 'Compulsion' ")
fig.show()

# %% [markdown]
# **Analysis of Q10 (compulsion/emotion/time/impairment)**

# %%
DfQ10 = finalDf.iloc[9:10]

# %%
DfQ10
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q10           29       1.0       1.0

# %%
DfQ10.loc['sum'] = DfQ10.sum()
DfQ10.loc['percentage'] = DfQ10.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1196120963.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1196120963.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DfQ10.loc['percentage']['Agree']= round((DfQ10.loc['sum']['Agree']/DfQ10.loc['sum'].sum())*100)
DfQ10.loc['percentage']['Disagree']= round((DfQ10.loc['sum']['Disagree']/DfQ10.loc['sum'].sum())*100)
DfQ10.loc['percentage']['Not sure']= round((DfQ10.loc['sum']['Not sure']/DfQ10.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ10= DfQ10.filter(items=['percentage'], axis=0)
dfPercentage_DfQ10.reset_index(inplace =True)
dfPercentage_DfQ10.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ10, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Compulsion' ")
fig.show()

# %% [markdown]
# **Analysis of Q11 (compulsion/activity)**

# %%
DfQ11 = finalDf.iloc[10:11]

# %%
DfQ11.loc['sum'] = DfQ11.sum()
DfQ11.loc['percentage'] = DfQ11.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/2903504548.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/2903504548.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DfQ11.loc['percentage']['Agree']= round((DfQ11.loc['sum']['Agree']/DfQ11.loc['sum'].sum())*100)
DfQ11.loc['percentage']['Disagree']= round((DfQ11.loc['sum']['Disagree']/DfQ11.loc['sum'].sum())*100)
DfQ11.loc['percentage']['Not sure']= round((DfQ11.loc['sum']['Not sure']/DfQ11.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ11= DfQ11.filter(items=['percentage'], axis=0)
dfPercentage_DfQ11.reset_index(inplace =True)
dfPercentage_DfQ11.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ11, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Compulsion as a distressful activity' ")
fig.show()

# %% [markdown]
# **Analysis of Q12 (compulsion/nagative statment)**

# %%
DfQ12 = finalDf.iloc[11:12]

# %%
DfQ12
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q12           10      14.0       7.0

# %%
DfQ12.loc['sum'] = DfQ12.sum()
DfQ12.loc['percentage'] = DfQ12.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/4292289829.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/4292289829.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DfQ12.loc['percentage']['Agree']= round((DfQ12.loc['sum']['Agree']/DfQ12.loc['sum'].sum())*100)
DfQ12.loc['percentage']['Disagree']= round((DfQ12.loc['sum']['Disagree']/DfQ12.loc['sum'].sum())*100)
DfQ12.loc['percentage']['Not sure']= round((DfQ12.loc['sum']['Not sure']/DfQ12.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ12= DfQ12.filter(items=['percentage'], axis=0)
dfPercentage_DfQ12.reset_index(inplace =True)
dfPercentage_DfQ12.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ12, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Negative statment of Compulsion ' ")
fig.show()

# %% [markdown]
# **Analysis of questions related to Obsession Q8 - Q9 **

# %%
DfQ8 = finalDf.iloc[7:8]

# %%
DfQ8.loc['sum'] = DfQ8.sum()
DfQ8.loc['percentage'] = DfQ8.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/2913886959.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/2913886959.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DfQ8.loc['percentage']['Agree']= round((DfQ8.loc['sum']['Agree']/DfQ8.loc['sum'].sum())*100)
DfQ8.loc['percentage']['Disagree']= round((DfQ8.loc['sum']['Disagree']/DfQ8.loc['sum'].sum())*100)
DfQ8.loc['percentage']['Not sure']= round((DfQ8.loc['sum']['Not sure']/DfQ8.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ8= DfQ8.filter(items=['percentage'], axis=0)
dfPercentage_DfQ8.reset_index(inplace =True)
dfPercentage_DfQ8.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ8, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Obsession ' ")
fig.show()

# %% [markdown]
# **Aggressive obsession**

# %%
DfQ9 = finalDf.iloc[8:9]

# %%
DfQ9.loc['sum'] = DfQ9.sum()
DfQ9.loc['percentage'] = DfQ9.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1379850834.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/1379850834.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DfQ9.loc['percentage']['Agree']= round((DfQ9.loc['sum']['Agree']/DfQ9.loc['sum'].sum())*100)
DfQ9.loc['percentage']['Disagree']= round((DfQ9.loc['sum']['Disagree']/DfQ9.loc['sum'].sum())*100)
DfQ9.loc['percentage']['Not sure']= round((DfQ9.loc['sum']['Not sure']/DfQ9.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ9= DfQ9.filter(items=['percentage'], axis=0)
dfPercentage_DfQ9.reset_index(inplace =True)
dfPercentage_DfQ9.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ9, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Aggressive obsession' ")
fig.show()

# %% [markdown]
# **Analysis of Q1  (negative emotion-intruisve thought)**

# %%
DfQ1 = finalDf.head(1)

# %%
DfQ1
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q1            22       7.0       2.0

# %%
DfQ1.loc['sum'] = DfQ1.sum()

# %%
DfQ1.loc['percentage'] = DfQ1.value_counts()

# %%
DfQ1.loc['percentage']['Agree']= round((DfQ1.loc['sum']['Agree']/DfQ1.loc['sum'].sum())*100)
DfQ1.loc['percentage']['Disagree']= round((DfQ1.loc['sum']['Disagree']/DfQ1.loc['sum'].sum())*100)
DfQ1.loc['percentage']['Not sure']= round((DfQ1.loc['sum']['Not sure']/DfQ1.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ1= DfQ1.filter(items=['percentage'], axis=0)
dfPercentage_DfQ1.reset_index(inplace =True)
dfPercentage_DfQ1.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ1, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Intrusive thought/ negative emotion' ")
fig.show()

# %%
DfQ2 = finalDf.iloc[1:2]
DfQ2
# Out:
#            Agree  Disagree  Not sure
# Questions
# Q2            30       1.0       0.0

# %%
DfQ2.loc['sum'] = DfQ2.sum()
DfQ2.loc['percentage'] = DfQ2.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/3127194569.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/3127194569.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DfQ2.loc['percentage']['Agree']= round((DfQ2.loc['sum']['Agree']/DfQ2.loc['sum'].sum())*100)
DfQ2.loc['percentage']['Disagree']= round((DfQ2.loc['sum']['Disagree']/DfQ2.loc['sum'].sum())*100)
DfQ2.loc['percentage']['Not sure']= round((DfQ2.loc['sum']['Not sure']/DfQ2.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ2= DfQ2.filter(items=['percentage'], axis=0)
dfPercentage_DfQ2.reset_index(inplace =True)
dfPercentage_DfQ2.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ2, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Intrusive thought/impairment' ")
fig.show()

# %%
DfQ3 = finalDf.iloc[2:3]

# %%
DfQ3.loc['sum'] = DfQ3.sum()
DfQ3.loc['percentage'] = DfQ3.value_counts()
# Out:
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/699837108.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/cn/1nntjl5j55bbps955b_pfclw0000gn/T/ipykernel_94417/699837108.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DfQ3.loc['percentage']['Agree']= round((DfQ3.loc['sum']['Agree']/DfQ3.loc['sum'].sum())*100)
DfQ3.loc['percentage']['Disagree']= round((DfQ3.loc['sum']['Disagree']/DfQ3.loc['sum'].sum())*100)
DfQ3.loc['percentage']['Not sure']= round((DfQ3.loc['sum']['Not sure']/DfQ3.loc['sum'].sum())*100)

# %%
dfPercentage_DfQ3= DfQ3.filter(items=['percentage'], axis=0)
dfPercentage_DfQ3.reset_index(inplace =True)
dfPercentage_DfQ3.reset_index(inplace =True)

# %%
import plotly.express as px

fig = px.bar(dfPercentage_DfQ3, x=["Agree", "Disagree", "Not sure"],height=200)
fig.update_layout(
    autosize=True,
    width=1000,
    height=300,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)

fig.update_xaxes(title_text="Responses")
fig.update_yaxes(title_text="'Intrusive thought/time-consuming' ")
fig.show()
